# %% [markdown]
# <a href="https://colab.research.google.com/github/fujitsuacet06-oss/BB84-QKD-Simulator/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pennylane
import pennylane as qml
import numpy as np
import matplotlib.pyplot as plt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.2/57.2 kB 2.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 56.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 935.6/935.6 kB 48.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 103.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 90.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.9/167.9 kB 12.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 117.3 MB/s eta 0:00:00
# ...

# %%
dev = qml.device("default.qubit", wires=2)
@qml.qnode(dev)
def quantum_circuit(x, weights):
    qml.AngleEmbedding(x, wires=range(2))
    qml.BasicEntanglerLayers(weights, wires=range(2))
    return qml.expval(qml.PauliZ(0))

# %%
X = np.array([[0.1, 0.2],
              [1.0, 1.1],
              [0.3, 0.4],
              [1.2, 1.3]])
Y = np.array([1, -1, 1, -1])

# %%
def cost(weights):
    loss = 0
    for x, y in zip(X, Y):
        pred = quantum_circuit(x, weights)
        loss += (pred - y) ** 2
    return loss / len(Y)

# %%
weights = np.random.random((1, 2))
opt = qml.GradientDescentOptimizer(stepsize=0.1)
losses = []
for i in range(20):
    weights = opt.step(cost, weights)
    l = cost(weights)
    losses.append(l)
    print(f"Epoch {i+1} | Loss: {l:.4f}")
# Out:
# Epoch 1 | Loss: 0.5226
# Epoch 2 | Loss: 0.5226
# Epoch 3 | Loss: 0.5226
# Epoch 4 | Loss: 0.5226
# Epoch 5 | Loss: 0.5226
# Epoch 6 | Loss: 0.5226
# Epoch 7 | Loss: 0.5226
# Epoch 8 | Loss: 0.5226
# Epoch 9 | Loss: 0.5226
# Epoch 10 | Loss: 0.5226
# Epoch 11 | Loss: 0.5226
# Epoch 12 | Loss: 0.5226
# Epoch 13 | Loss: 0.5226
# Epoch 14 | Loss: 0.5226
# Epoch 15 | Loss: 0.5226
# Epoch 16 | Loss: 0.5226
# Epoch 17 | Loss: 0.5226
# Epoch 18 | Loss: 0.5226
# Epoch 19 | Loss: 0.5226
# Epoch 20 | Loss: 0.5226
# /usr/local/lib/python3.12/dist-packages/pennylane/_grad/grad.py:337: UserWarning: Attempted to differentiate a function with no trainable parameters. If this is unintended, please add trainable parameters via the 'requires_grad' attribute or 'argnums' keyword.
#   warnings.warn(

# %%
plt.plot(losses)
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Quantum Model Training Loss")
plt.show()

# %%
correct = 0
for x, y in zip(X, Y):
    if np.sign(quantum_circuit(x, weights)) == y:
        correct += 1
quantum_acc = correct / len(Y)
print("Quantum Accuracy:", quantum_acc)
# Out:
# Quantum Accuracy: 0.75

# %%
classical_acc = 0.75
models = ["Classical", "Quantum"]
accuracy = [classical_acc, quantum_acc]
plt.bar(models, accuracy)
plt.ylabel("Accuracy")
plt.title("Classical vs Quantum Accuracy")
plt.show()
